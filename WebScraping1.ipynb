# %%
# import requests

# %%
# web=requests.get("https://www.youtube.com/")
# print(web)
# Out:
# <Response [200]>

# %%
# web.content

# %%
import requests
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.youtube.com/")

# %%
web
# Out:
# <Response [200]>

# %%
web.content
# Out:
# b'<!DOCTYPE html><html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="en-GB" darker-dark-theme darker-dark-theme-deprecate system-icons typography typography-spacing><head><script data-id="_gd" nonce="sH9eVYJqJ3wjm_NW96YDsg">window.WIZ_global_data = {"MUE6Ne":"youtube_web","MuJWjd":false,"UUFaWc":"%.@.null,1000,2]","cfb2h":"youtube.web-front-end-critical_20250415.08_p0","fPDxwd":[],"iCzhFc":false,"nQyAE":{},"oxN3nb":{"1":false,"0":false,"610401301":false,"899588437":false,"725719775":false,"513659523":false,"568333945":false,"1331761403":false,"651175828":false,"722764542":false,"1981196515":false},"u4g7r":"%.@.null,1,2]","vJQk6":false,"xnI9P":true,"xwAfE":true,"yFnxrf":2486};</script><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta http-equiv="origin-trial" content="ApvK67ociHgr2egd6c2ZjrfPuRs8BHcvSggogIOPQNH7GJ3cVlyJ1NOq/COCdj0+zxskqHt9HgLLETc8qqD+vwsAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLC
# ...

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html darker-dark-theme="" darker-dark-theme-deprecate="" lang="en-GB" style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" system-icons="" typography="" typography-spacing="">
#  <head>
#   <script data-id="_gd" nonce="sH9eVYJqJ3wjm_NW96YDsg">
#    window.WIZ_global_data = {"MUE6Ne":"youtube_web","MuJWjd":false,"UUFaWc":"%.@.null,1000,2]","cfb2h":"youtube.web-front-end-critical_20250415.08_p0","fPDxwd":[],"iCzhFc":false,"nQyAE":{},"oxN3nb":{"1":false,"0":false,"610401301":false,"899588437":false,"725719775":false,"513659523":false,"568333945":false,"1331761403":false,"651175828":false,"722764542":false,"1981196515":false},"u4g7r":"%.@.null,1,2]","vJQk6":false,"xnI9P":true,"xwAfE":true,"yFnxrf":2486};
#   </script>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# ...

# %%
soup.title
# Out:
# <title>YouTube</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.a
# Out:
# <a href="/" style="display: none;" title="YouTube"><svg class="external-icon" height="18" id="yt-ringo2-svg" viewbox="0 0 104 18" width="104" xmlns="http://www.w3.org/2000/svg"><defs><clippath id="clip0_161_5084"><rect height="18" width="104"></rect></clippath></defs><g clip-path="url(#clip0_161_5084)"><path d="M13.0363 18C13.0363 18 21.2125 18 23.2406 17.46C24.3825 17.154 25.2413 16.272 25.5427 15.183C26.1 13.185 26.1 8.982 26.1 8.982C26.1 8.982 26.1 4.806 25.5427 2.826C25.2413 1.71 24.3825 0.846 23.2406 0.549C21.2125 0 13.0363 0 13.0363 0C13.0363 0 4.87833 0 2.8594 0.549C1.73574 0.846 0.858733 1.71 0.538992 2.826C0 4.806 0 8.982 0 8.982C0 8.982 0 13.185 0.538992 15.183C0.858733 16.272 1.73574 17.154 2.8594 17.46C4.87833 18 13.0363 18 13.0363 18Z" fill="#FF0000"></path><path d="M17.1 8.99999L10.35 5.17499V12.825L17.1 8.99999Z" fill="white"></path><path d="M104 0V18" stroke="grey" stroke-width="0.5"></path><g id="youtube-paths"><path d="M34.2685 18.0201V12.4901L37.7785 1.00012H34.918
# ...

# %%
soup.p

# %%
tag=soup.html

# %%
type(tag)
# Out:
# bs4.element.Tag

# %%
tag=soup.p

# %%
print(tag)
# Out:
# None

# %%
tag=soup.h1
tag

# %%
tag=soup.div
tag
# Out:
# <div class="ytd-searchbox-spt" id="search-container" slot="search-container"></div>

# %%
 tag=soup.a.string
tag

# %%
soup.head
# Out:
# <head><script data-id="_gd" nonce="sH9eVYJqJ3wjm_NW96YDsg">window.WIZ_global_data = {"MUE6Ne":"youtube_web","MuJWjd":false,"UUFaWc":"%.@.null,1000,2]","cfb2h":"youtube.web-front-end-critical_20250415.08_p0","fPDxwd":[],"iCzhFc":false,"nQyAE":{},"oxN3nb":{"1":false,"0":false,"610401301":false,"899588437":false,"725719775":false,"513659523":false,"568333945":false,"1331761403":false,"651175828":false,"722764542":false,"1981196515":false},"u4g7r":"%.@.null,1,2]","vJQk6":false,"xnI9P":true,"xwAfE":true,"yFnxrf":2486};</script><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="ApvK67ociHgr2egd6c2ZjrfPuRs8BHcvSggogIOPQNH7GJ3cVlyJ1NOq/COCdj0+zxskqHt9HgLLETc8qqD+vwsAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLCJleHBpcnkiOjE2OTUxNjc5OTksImlzU3ViZG9tYWluIjp0cnVlfQ==" http-equiv="origin-trial"/><script nonce="sH9eVYJqJ3wjm_NW96YDsg">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:func
# ...

# %%
soup.find_all("a")
# Out:
# [<a href="/" style="display: none;" title="YouTube"><svg class="external-icon" height="18" id="yt-ringo2-svg" viewbox="0 0 104 18" width="104" xmlns="http://www.w3.org/2000/svg"><defs><clippath id="clip0_161_5084"><rect height="18" width="104"></rect></clippath></defs><g clip-path="url(#clip0_161_5084)"><path d="M13.0363 18C13.0363 18 21.2125 18 23.2406 17.46C24.3825 17.154 25.2413 16.272 25.5427 15.183C26.1 13.185 26.1 8.982 26.1 8.982C26.1 8.982 26.1 4.806 25.5427 2.826C25.2413 1.71 24.3825 0.846 23.2406 0.549C21.2125 0 13.0363 0 13.0363 0C13.0363 0 4.87833 0 2.8594 0.549C1.73574 0.846 0.858733 1.71 0.538992 2.826C0 4.806 0 8.982 0 8.982C0 8.982 0 13.185 0.538992 15.183C0.858733 16.272 1.73574 17.154 2.8594 17.46C4.87833 18 13.0363 18 13.0363 18Z" fill="#FF0000"></path><path d="M17.1 8.99999L10.35 5.17499V12.825L17.1 8.99999Z" fill="white"></path><path d="M104 0V18" stroke="grey" stroke-width="0.5"></path><g id="youtube-paths"><path d="M34.2685 18.0201V12.4901L37.7785 1.00012H34.91
# ...

# %%
com=soup.div.string

# %%
com

# %%
print(soup.body.prettify())
# Out:
# <body dir="ltr">
#  <script nonce="sH9eVYJqJ3wjm_NW96YDsg">
#   if (window.ytcsi) {window.ytcsi.tick('bs', null, '');}
#  </script>
#  <script nonce="sH9eVYJqJ3wjm_NW96YDsg">
#   ytcfg.set('initialBodyClientWidth', document.body.clientWidth);
#  </script>
#  <script nonce="sH9eVYJqJ3wjm_NW96YDsg">
#   if (window.ytcsi) {window.ytcsi.tick('ai', null, '');}
#  </script>
#  <iframe name="passive_signin" src="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den-GB%26next%3D%252Fsignin_passive%26feature%3Dpassive&amp;hl=en-GB" style="display: none">
#  </iframe>
#  <ytd-app>
#   <ytd-masthead class="shell" id="masthead" logo-type="YOUTUBE_LOGO" slot="masthead">
#    <div class="ytd-searchbox-spt" id="search-container" slot="search-container">
#    </div>
#    <div class="ytd-searchbox-spt" id="search-input" slot="search-input">
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
web.content
# Out:
# b'<!DOCTYPE html><html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="en-GB" darker-dark-theme darker-dark-theme-deprecate system-icons typography typography-spacing><head><script data-id="_gd" nonce="sH9eVYJqJ3wjm_NW96YDsg">window.WIZ_global_data = {"MUE6Ne":"youtube_web","MuJWjd":false,"UUFaWc":"%.@.null,1000,2]","cfb2h":"youtube.web-front-end-critical_20250415.08_p0","fPDxwd":[],"iCzhFc":false,"nQyAE":{},"oxN3nb":{"1":false,"0":false,"610401301":false,"899588437":false,"725719775":false,"513659523":false,"568333945":false,"1331761403":false,"651175828":false,"722764542":false,"1981196515":false},"u4g7r":"%.@.null,1,2]","vJQk6":false,"xnI9P":true,"xwAfE":true,"yFnxrf":2486};</script><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta http-equiv="origin-trial" content="ApvK67ociHgr2egd6c2ZjrfPuRs8BHcvSggogIOPQNH7GJ3cVlyJ1NOq/COCdj0+zxskqHt9HgLLETc8qqD+vwsAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLC
# ...

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html darker-dark-theme="" darker-dark-theme-deprecate="" lang="en-GB" style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" system-icons="" typography="" typography-spacing="">
#  <head>
#   <script data-id="_gd" nonce="sH9eVYJqJ3wjm_NW96YDsg">
#    window.WIZ_global_data = {"MUE6Ne":"youtube_web","MuJWjd":false,"UUFaWc":"%.@.null,1000,2]","cfb2h":"youtube.web-front-end-critical_20250415.08_p0","fPDxwd":[],"iCzhFc":false,"nQyAE":{},"oxN3nb":{"1":false,"0":false,"610401301":false,"899588437":false,"725719775":false,"513659523":false,"568333945":false,"1331761403":false,"651175828":false,"722764542":false,"1981196515":false},"u4g7r":"%.@.null,1,2]","vJQk6":false,"xnI9P":true,"xwAfE":true,"yFnxrf":2486};
#   </script>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# ...

# %%
class_d=soup.find("div",class_="rich-grid-media-skeleton")

# %%
class_d
# Out:
# <div class="rich-grid-media-skeleton" style="min-width: 310px; flex-basis: 310px;"><div class="video-details"><div class="rich-thumbnail skeleton-bg-color"></div><div class="details"><div class="channel-avatar skeleton-bg-color"></div><div class="details-text-shell"><div class="rich-video-title text-shell skeleton-bg-color"></div><div class="rich-video-meta text-shell skeleton-bg-color"></div></div></div></div></div>

# %%
for i in soup.find_all("a"):
    print(i.get("href"))
# Out:
# /
# /
# https://www.youtube.com/about/
# https://www.youtube.com/about/press/
# https://www.youtube.com/about/copyright/
# /t/contact_us/
# https://www.youtube.com/creators/
# https://www.youtube.com/ads/
# https://developers.google.com/youtube
# /t/terms
# /t/privacy
# https://www.youtube.com/about/policies/
# https://www.youtube.com/howyoutubeworks?utm_campaign=ytgen&utm_source=ythp&utm_medium=LeftNav&utm_content=txt&u=https%3A%2F%2Fwww.youtube.com%2Fhowyoutubeworks%3Futm_source%3Dythp%26utm_medium%3DLeftNav%26utm_campaign%3Dytgen
# /new

# %%
img=soup.find_all("img")
img
# Out:
# []

# %%
weby=requests.get("https://www.youtube.com/howyoutubeworks/?utm_campaign=ytgen&utm_source=ythp&utm_medium=LeftNav&utm_content=txt&u=https%3A%2F%2Fwww.youtube.com%2Fhowyoutubeworks%3Futm_source%3Dythp%26utm_medium%3DLeftNav%26utm_campaign%3Dytgen")
weby
# Out:
# <Response [200]>

# %%
weby.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <script nonce="-UImzHKBNqdo_OlHBO9rNw">\n      function glueCookieNotificationBarLoaded() {\n        (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n        new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n        j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n        \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n        })(window,document,\'script\',\'dataLayer\',\'GTM-56HCXDK\');\n      }\n    </script>\n\n    <meta name="google-site-verification" content="zt7eFdaG8wQDdn6zYXGDJA7Sst9YZB07H-5iTgWpH1k">\n\n    <meta charset="utf-8">\n    <meta content="IE=Edge" http-equiv="X-UA-Compatible">\n    <meta name="viewport" content="initial-scale=1, minimum-scale=1, width=device-width">\n    <meta http-equiv="x-dns-prefetch-control" content="on">\n\n\n      <title>How YouTube Works \xe2\x80\x93 product features, responsibility and
# ...

# %%
soup=BeautifulSoup(weby.content,"html.parser")

# %%
h=soup.find_all("h1")
h
# Out:
# [<h1><span class="lb-font-weight-600 lb-font-beta-headline">
#      Ever wonder how YouTube works?
#    </span></h1>]

# %%
img=soup.find_all("img")
img
# Out:
# [<img alt="YouTube" border="0" class="lb-header__logo lb-header-js-logo" src="https://www.gstatic.com/youtube/img/branding/youtubelogo/svg/youtubelogo.svg"/>,
# ...

# %%
for i in img:
    print(i.get("src"))
    print(type(i.get("src")))
# Out:
# https://www.gstatic.com/youtube/img/branding/youtubelogo/svg/youtubelogo.svg
# <class 'str'>
# https://lh3.googleusercontent.com/u0trDWfXYEdAjjoAnLXPnj9n0jTFeI8zOBTaz63K-jv-Km-8xQ0qYdCCriEkbnveOsN9layXOrGGQjkjB8NkKb3eNqK0f2yu2MT02Q=v3-s20-fblur=1,20
# <class 'str'>
# https://lh3.googleusercontent.com/j47AKxBbSsYNdEe_X-5wCqUeK_jFHFPWyk5xDeMF1AyCR6DqIRi66260SCiaDXWh0F5pKhFQ595NbkZ_4IiD7FMwsLgNBvgFMF8j-w=v3-s20-fblur=1,20
# <class 'str'>
# https://lh3.googleusercontent.com/bhPC00yAzTN2aG9dGTpdWpz95V_r9iPNTO9mgJz3_-ApIv2qqX-p_-i5VWVZjgw9L_rHVvgW0f8Y1UZ7y85z69lnk9GjGOqo61VXH5k=v3-s20-fblur=1,20
# <class 'str'>
# https://lh3.googleusercontent.com/-HF3gU9h5pacSjfbFqC3hVWsvE6x2xxfChTt61sweKjl4BQ7VAvlFgYKve93ToxhIOjl7bBYgxfx7FTUS2Ps0kShn-NQi9VJfMTP=v3-s20-fblur=1,20
# <class 'str'>
# https://lh3.googleusercontent.com/EJWOf48vHpXf4PXxUUCLfiGHupMTgHfK5p3Mjkm5LCTjK7W0VqOVEPsiDwdxIo8lwgUbjGf6_sTj3iZUVADFxEOQ1d8l72GgL8JL=v3-s20-fblur=1,20
# <class 'str'>
# ...
